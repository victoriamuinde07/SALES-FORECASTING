# %% [markdown]
# ### PROJECT DESCRIPTION

# %% [markdown]
# This store sales forecasting project offers a valuable resource for businesses operating in the retail furniture sector.
# By analyzing historical sales data from the superstore dataset, users can gain insights into future sales patterns and trends.
# This information can be utilized to optimize inventory management strategies, anticipate customer demand, and enhance overall operational efficiency.

# %%
import pandas as pd

# %%
holiday_df = pd.read_csv('datasets/holidays_events.csv')
print(holiday_df.shape)
print(holiday_df.info())
holiday_df.head()
# Out:
# (350, 6)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         350 non-null    object
#  1   type         350 non-null    object
#  2   locale       350 non-null    object
#  3   locale_name  350 non-null    object
#  4   description  350 non-null    object
#  5   transferred  350 non-null    bool
# dtypes: bool(1), object(5)
# memory usage: 14.1+ KB
# None
#          date     type    locale locale_name                    description  \
# 0  2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1  2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2  2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 3  2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 4  2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
#
#    transferred
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
oil_df = pd.read_csv('datasets/oil.csv') 
print(oil_df.shape)
print(oil_df.info()) 
oil_df.head()
# Out:
# (1218, 2)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1218 non-null   object
#  1   dcoilwtico  1175 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 19.2+ KB
# None
#          date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20

# %%
store_df = pd.read_csv('datasets/stores.csv') 
print(store_df.shape)
print(store_df.info())
store_df.head()
# Out:
# (54, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   store_nbr  54 non-null     int64
#  1   city       54 non-null     object
#  2   state      54 non-null     object
#  3   type       54 non-null     object
#  4   cluster    54 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 2.2+ KB
# None
#    store_nbr           city                           state type  cluster
# 0          1          Quito                       Pichincha    D       13
# 1          2          Quito                       Pichincha    D       13
# 2          3          Quito                       Pichincha    D        8
# 3          4          Quito                       Pichincha    D        9
# 4          5  Santo Domingo  Santo Domingo de los Tsachilas    D        4

# %%
test_df = pd.read_csv('datasets/test.csv') 
print(test_df.shape)
print(test_df.info())
test_df.head()
# Out:
# (28512, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28512 entries, 0 to 28511
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           28512 non-null  int64
#  1   date         28512 non-null  object
#  2   store_nbr    28512 non-null  int64
#  3   family       28512 non-null  object
#  4   onpromotion  28512 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 1.1+ MB
# None
#         id        date  store_nbr      family  onpromotion
# 0  3000888  2017-08-16          1  AUTOMOTIVE            0
# 1  3000889  2017-08-16          1   BABY CARE            0
# 2  3000890  2017-08-16          1      BEAUTY            2
# 3  3000891  2017-08-16          1   BEVERAGES           20
# 4  3000892  2017-08-16          1       BOOKS            0

# %%
train_df = pd.read_csv('datasets/train.csv') 
print(train_df.shape)
print(train_df.info)
train_df.head()
# Out:
# (3000888, 6)
# <bound method DataFrame.info of               id        date  store_nbr                      family     sales  \
# 0              0  2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1  2013-01-01          1                   BABY CARE     0.000
# 2              2  2013-01-01          1                      BEAUTY     0.000
# 3              3  2013-01-01          1                   BEVERAGES     0.000
# 4              4  2013-01-01          1                       BOOKS     0.000
# ...          ...         ...        ...                         ...       ...
# 3000883  3000883  2017-08-15          9                     POULTRY   438.133
# 3000884  3000884  2017-08-15          9              PREPARED FOODS   154.553
# 3000885  3000885  2017-08-15          9                     PRODUCE  2419.729
# 3000886  3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  3000887  2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 3000883            0
# 3000884            1
# 3000885          148
# 3000886            8
# 3000887            0
#
# [3000888 rows x 6 columns]>
#    id        date  store_nbr      family  sales  onpromotion
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0
# 1   1  2013-01-01          1   BABY CARE    0.0            0
# 2   2  2013-01-01          1      BEAUTY    0.0            0
# 3   3  2013-01-01          1   BEVERAGES    0.0            0
# 4   4  2013-01-01          1       BOOKS    0.0            0

# %%
transaction_df = pd.read_csv('datasets/transactions.csv')
print(transaction_df.shape)
print(transaction_df.info()) 
transaction_df.head()
# Out:
# (83488, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83488 entries, 0 to 83487
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          83488 non-null  object
#  1   store_nbr     83488 non-null  int64
#  2   transactions  83488 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 1.9+ MB
# None
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %% [markdown]
# #### checking for null values in the datasets

# %%
holiday_df.isna().sum()
# Out:
# date           0
# type           0
# locale         0
# locale_name    0
# description    0
# transferred    0
# dtype: int64

# %%
oil_df.isna().sum()
# Out:
# date           0
# dcoilwtico    43
# dtype: int64

# %%
store_df.isna().sum()
# Out:
# store_nbr    0
# city         0
# state        0
# type         0
# cluster      0
# dtype: int64

# %%
train_df.isna().sum()
# Out:
# id             0
# date           0
# store_nbr      0
# family         0
# sales          0
# onpromotion    0
# dtype: int64

# %%
transaction_df.isna().sum()
# Out:
# date            0
# store_nbr       0
# transactions    0
# dtype: int64

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# Converting time to timestamps

# %%
def timestamps(df):
    df['date'] = pd.to_datetime(df['date'])
    df['weekday'] = df['date'].dt.weekday
    df['month'] = df['date'].dt.month 
    df['day_of_year'] = df['date'].dt.dayofyear
    df['quarter'] = df['date'].dt.quarter
    
    
    df = df.drop(columns=['date']) 
    return df

# %%
holiday_df = timestamps(holiday_df)
holiday_df.head()
# Out:
#       type    locale locale_name                    description  transferred  \
# 0  Holiday     Local       Manta             Fundacion de Manta        False
# 1  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi        False
# 2  Holiday     Local      Cuenca            Fundacion de Cuenca        False
# 3  Holiday     Local    Libertad      Cantonizacion de Libertad        False
# 4  Holiday     Local    Riobamba      Cantonizacion de Riobamba        False
#
#    weekday  month  day_of_year  quarter
# 0        4      3           62        1
# 1        6      4           92        2
# 2        3      4          103        2
# 3        5      4          105        2
# 4        5      4          112        2

# %%
oil_df = timestamps(oil_df)
oil_df.head()
# Out:
#    dcoilwtico  weekday  month  day_of_year  quarter
# 0         NaN        1      1            1        1
# 1       93.14        2      1            2        1
# 2       92.97        3      1            3        1
# 3       93.12        4      1            4        1
# 4       93.20        0      1            7        1

# %%
test_df = timestamps(test_df)
test_df.head()
# Out:
#         id  store_nbr      family  onpromotion  weekday  month  day_of_year  \
# 0  3000888          1  AUTOMOTIVE            0        2      8          228
# 1  3000889          1   BABY CARE            0        2      8          228
# 2  3000890          1      BEAUTY            2        2      8          228
# 3  3000891          1   BEVERAGES           20        2      8          228
# 4  3000892          1       BOOKS            0        2      8          228
#
#    quarter
# 0        3
# 1        3
# 2        3
# 3        3
# 4        3

# %%
train_df = timestamps(train_df)
train_df.head()
# Out:
#    id  store_nbr      family  sales  onpromotion  weekday  month  day_of_year  \
# 0   0          1  AUTOMOTIVE    0.0            0        1      1            1
# 1   1          1   BABY CARE    0.0            0        1      1            1
# 2   2          1      BEAUTY    0.0            0        1      1            1
# 3   3          1   BEVERAGES    0.0            0        1      1            1
# 4   4          1       BOOKS    0.0            0        1      1            1
#
#    quarter
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %%
transaction_df = timestamps(transaction_df)
transaction_df.head()
# Out:
#    store_nbr  transactions  weekday  month  day_of_year  quarter
# 0         25           770        1      1            1        1
# 1          1          2111        2      1            2        1
# 2          2          2358        2      1            2        1
# 3          3          3487        2      1            2        1
# 4          4          1922        2      1            2        1

# %%
# Ensure each DataFrame's 'Timestamp' column is in datetime format
dataframes = [
    holiday_df,
    oil_df,
    transaction_df,
    train_df
]



# Now concatenate all DataFrames along the rows
merged_data = pd.concat(dataframes, ignore_index=True)

# Sort by 'Timestamp' and reset the index
merged_data = merged_data.sort_values(by='year').reset_index(drop=True)

# Display the merged DataFrame
print(merged_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15088\869343054.py in ?()
#      11 # Now concatenate all DataFrames along the rows
#      12 merged_data = pd.concat(dataframes, ignore_index=True)
#      13
#      14 # Sort by 'Timestamp' and reset the index
# ---> 15 merged_data = merged_data.sort_values(by='year').reset_index(drop=True)
#      16
#      17 # Display the merged DataFrame
#      18 print(merged_data)
#
# c:\Users\pc\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6940             )
#    6941         elif len(by):
#    6942             # len(by) == 1
#    6943
# -> 6944             k = self._get_label_or_level_values(by[0], axis=axis)
#    6945
#    6946             # need to rewrap column in Series to apply key function
#    6947             if key is not None:
#
# c:\Users\pc\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1840             values = self.xs(key, axis=other_axes[0])._values
#    1841         elif self._is_level_reference(key, axis=axis):
#    1842             values = self.axes[axis].get_level_values(key)._values
#    1843         else:
# -> 1844             raise KeyError(key)
#    1845
#    1846         # Check for duplicates
#    1847         if values.ndim > 1:
#
# KeyError: 'year'

# %%
merged_data.head()
# Out:
#       type    locale                     locale_name  \
# 0  Holiday     Local                           Manta
# 1  Holiday  Regional  Santo Domingo de los Tsachilas
# 2  Holiday  Regional                     Santa Elena
# 3  Holiday     Local                        Guaranda
# 4  Holiday     Local                       Latacunga
#
#                           description transferred  year  month  day  \
# 0                  Fundacion de Manta       False  2012      3    2
# 1  Provincializacion de Santo Domingo       False  2012     11    6
# 2       Provincializacion Santa Elena       False  2012     11    7
# 3           Independencia de Guaranda       False  2012     11   10
# 4          Independencia de Latacunga       False  2012     11   11
#
#    dcoilwtico  store_nbr  transactions  id family  sales  onpromotion
# 0         NaN        NaN           NaN NaN    NaN    NaN          NaN
# 1         NaN        NaN           NaN NaN    NaN    NaN          NaN
# 2         NaN        NaN           NaN NaN    NaN    NaN          NaN
# 3         NaN        NaN           NaN NaN    NaN    NaN          NaN
# 4         NaN        NaN           NaN NaN    NaN    NaN          NaN

# %%
merged_data = pd.merge(merged_data, store_df, on='store_nbr', how='left')
merged_data.head()
# Out:
#     type_x    locale                     locale_name  \
# 0  Holiday     Local                           Manta
# 1  Holiday  Regional  Santo Domingo de los Tsachilas
# 2  Holiday  Regional                     Santa Elena
# 3  Holiday     Local                        Guaranda
# 4  Holiday     Local                       Latacunga
#
#                           description transferred  year  month  day  \
# 0                  Fundacion de Manta       False  2012      3    2
# 1  Provincializacion de Santo Domingo       False  2012     11    6
# 2       Provincializacion Santa Elena       False  2012     11    7
# 3           Independencia de Guaranda       False  2012     11   10
# 4          Independencia de Latacunga       False  2012     11   11
#
#    dcoilwtico  store_nbr  transactions  id family  sales  onpromotion city  \
# 0         NaN        NaN           NaN NaN    NaN    NaN          NaN  NaN
# 1         NaN        NaN           NaN NaN    NaN    NaN          NaN  NaN
# 2         NaN        NaN           NaN NaN    NaN    NaN          NaN  NaN
# 3         NaN        NaN           NaN NaN    NaN    NaN          NaN  NaN
# 4         NaN        NaN           NaN NaN    NaN    NaN          NaN  NaN
#
#   state type_y  cluster
# 0   NaN    NaN      NaN
# 1   NaN    NaN      NaN
# 2   NaN    NaN      NaN
# 3   NaN    NaN      NaN
# 4   NaN    NaN      NaN

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3085944 entries, 0 to 3085943
# Data columns (total 19 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   type_x        object
#  1   locale        object
#  2   locale_name   object
#  3   description   object
#  4   transferred   object
#  5   year          int32
#  6   month         int32
#  7   day           int32
#  8   dcoilwtico    float64
#  9   store_nbr     float64
#  10  transactions  float64
#  11  id            float64
#  12  family        object
#  13  sales         float64
#  14  onpromotion   float64
#  15  city          object
#  16  state         object
#  17  type_y        object
#  18  cluster       float64
# dtypes: float64(7), int32(3), object(9)
# memory usage: 412.0+ MB

# %%
merged_data.isna().sum()
# Out:
# type_x          3085594
# locale          3085594
# locale_name     3085594
# description     3085594
# transferred     3085594
# year                  0
# month                 0
# day                   0
# dcoilwtico      3084769
# store_nbr          1568
# transactions    3002456
# id                85056
# family            85056
# sales             85056
# onpromotion       85056
# city               1568
# state              1568
# type_y             1568
# cluster            1568
# dtype: int64

# %% [markdown]
# Dropping unwanted columns having over 3million nun values this could peotentially mess with the analysis

# %%
merged_data.drop(columns=['type_x','locale','locale_name','description','transferred'])
# Out:
#          year  month  day  dcoilwtico  store_nbr  transactions         id  \
# 0        2012      3    2         NaN        NaN           NaN        NaN
# 1        2012     11    6         NaN        NaN           NaN        NaN
# 2        2012     11    7         NaN        NaN           NaN        NaN
# 3        2012     11   10         NaN        NaN           NaN        NaN
# 4        2012     11   11         NaN        NaN           NaN        NaN
# ...       ...    ...  ...         ...        ...           ...        ...
# 3085939  2017      3   13         NaN       11.0           NaN  2722989.0
# 3085940  2017      3   13         NaN       11.0           NaN  2722988.0
# 3085941  2017      3   13         NaN       11.0           NaN  2722987.0
# 3085942  2017      3   13         NaN       12.0           NaN  2722997.0
# 3085943  2017      8   15         NaN        9.0           NaN  3000887.0
#
#                           family  sales  onpromotion       city      state  \
# 0                            NaN    NaN          NaN        NaN        NaN
# 1                            NaN    NaN          NaN        NaN        NaN
# 2                            NaN    NaN          NaN        NaN        NaN
# 3                            NaN    NaN          NaN        NaN        NaN
# 4                            NaN    NaN          NaN        NaN        NaN
# ...                          ...    ...          ...        ...        ...
# 3085939  PLAYERS AND ELECTRONICS   12.0          0.0    Cayambe  Pichincha
# 3085940             PET SUPPLIES    3.0          0.0    Cayambe  Pichincha
# 3085941            PERSONAL CARE  364.0         16.0    Cayambe  Pichincha
# 3085942                   BEAUTY    2.0          1.0  Latacunga   Cotopaxi
# 3085943                  SEAFOOD   16.0          0.0      Quito  Pichincha
#
#         type_y  cluster
# 0          NaN      NaN
# 1          NaN      NaN
# 2          NaN      NaN
# 3          NaN      NaN
# 4          NaN      NaN
# ...        ...      ...
# 3085939      B      6.0
# 3085940      B      6.0
# 3085941      B      6.0
# 3085942      C     15.0
# 3085943      B      6.0
#
# [3085944 rows x 14 columns]

# %%
merged_data['dcoilwtico'].ffill(inplace= True)

# %%
merged_data['sales'].fillna(0, inplace=True)

# %%
merged_data['onpromotion'].fillna(0, inplace=True)

# %%
merged_data.isna().sum()
# Out:
# type_x          3085594
# locale          3085594
# locale_name     3085594
# description     3085594
# transferred     3085594
# year                  0
# month                 0
# day                   0
# dcoilwtico       466236
# store_nbr          1568
# transactions    3002456
# id                85056
# family            85056
# sales                 0
# onpromotion           0
# city               1568
# state              1568
# type_y             1568
# cluster            1568
# dtype: int64

# %%
merged_data['transactions'].fillna(merged_data['transactions'].median(), inplace=True)

# %%
merged_data.dropna(subset=['store_nbr', 'family'], inplace=True)

# %%
merged_data.isna().sum()
# Out:
# type_x          3000888
# locale          3000888
# locale_name     3000888
# description     3000888
# transferred     3000888
# year                  0
# month                 0
# day                   0
# dcoilwtico       460282
# store_nbr             0
# transactions          0
# id                    0
# family                0
# sales                 0
# onpromotion           0
# city                  0
# state                 0
# type_y                0
# cluster               0
# dtype: int64

# %% [markdown]
# type_x, locale, locale_name, description, transferred
#
# These columns have a high number of missing values, mostly in rows without holiday information.
# Since not every date is a holiday, it makes sense to fill these missing values with a placeholder like "None" or "No Holiday.""

# %%
# Fill missing holiday-related columns with 'None' or similar placeholder
merged_data['type_x'].fillna('No Holiday', inplace=True)
merged_data['locale'].fillna('No Locale', inplace=True)
merged_data['locale_name'].fillna('No Locale Name', inplace=True)
merged_data['description'].fillna('No Description', inplace=True)
merged_data['transferred'].fillna(False, inplace=True)

# Fill missing oil prices using forward fill method, backfill if necessary
merged_data['dcoilwtico'].fillna(method='ffill', inplace=True)
merged_data['dcoilwtico'].fillna(method='bfill', inplace=True)

# Set missing transactions to 0
merged_data['transactions'].fillna(0, inplace=True)

# Set missing sales and onpromotion values to 0
merged_data['sales'].fillna(0, inplace=True)
merged_data['onpromotion'].fillna(0, inplace=True)

# Fill missing store-related data (city, state, type, cluster) with placeholders or drop if necessary
merged_data['city'].fillna('Unknown City', inplace=True)
merged_data['state'].fillna('Unknown State', inplace=True)
merged_data['type_y'].fillna('Unknown Type', inplace=True)
merged_data['cluster'].fillna(-1, inplace=True)

# Drop rows with missing 'id' as they may not represent transactions
merged_data.dropna(subset=['id'], inplace=True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_4428\3919061564.py:9: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   merged_data['dcoilwtico'].fillna(method='ffill', inplace=True)
# C:\Users\pc\AppData\Local\Temp\ipykernel_4428\3919061564.py:10: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   merged_data['dcoilwtico'].fillna(method='bfill', inplace=True)
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[117], line 26
#      23 merged_data['cluster'].fillna(-1, inplace=True)
#      25 # Drop rows with missing 'id' as they may not represent transactions
# ---> 26 merged_data.dropna(subset=['id'], inplace=True)
#
# File c:\Users\pc\anaconda3\Lib\site-packages\pandas\core\frame.py:6434, in DataFrame.dropna(self, axis, how, thresh, subset, inplace, ignore_index)
#    6431     raise ValueError(f"invalid how option: {how}")
#    6433 if np.all(mask):
# -> 6434     result = self.copy(deep=None)
#    6435 else:
#    6436     result = self.loc(axis=axis)[mask]
#
# File c:\Users\pc\anaconda3\Lib\site-packages\pandas\core\generic.py:6685, in NDFrame.copy(self, deep)
#    6553 @final
#    6554 def copy(self, deep: bool_t | None = True) -> Self:
#    6555     """
#    6556     Make a copy of this object's indices and data.
#    6557
#    (...)
#    6683     dtype: int64
#    6684     """
# -> 6685     data = self._mgr.copy(deep=deep)
#    6686     self._clear_item_cache()
#    6687     return self._constructor_from_mgr(data, axes=data.axes).__finalize__(
#    6688         self, method="copy"
#    6689     )
#
# File c:\Users\pc\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:576, in BaseBlockManager.copy(self, deep)
#     573     else:
#     574         new_axes = list(self.axes)
# --> 576 res = self.apply("copy", deep=deep)
#     577 res.axes = new_axes
#     579 if self.ndim > 1:
#     580     # Avoid needing to re-compute these
#
# File c:\Users\pc\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\pc\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:645, in Block.copy(self, deep)
#     643 refs: BlockValuesRefs | None
#     644 if deep:
# --> 645     values = values.copy()
#     646     refs = None
#     647 else:
#
# MemoryError: Unable to allocate 137. MiB for an array with shape (6, 3000888) and data type float64

# %%
merged_data.isna().sum()
# Out:
# type_x          0
# locale          0
# locale_name     0
# description     0
# transferred     0
# year            0
# month           0
# day             0
# dcoilwtico      0
# store_nbr       0
# transactions    0
# id              0
# family          0
# sales           0
# onpromotion     0
# city            0
# state           0
# type_y          0
# cluster         0
# dtype: int64

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3000888 entries, 41 to 3085943
# Data columns (total 19 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   type_x        object
#  1   locale        object
#  2   locale_name   object
#  3   description   object
#  4   transferred   bool
#  5   year          int32
#  6   month         int32
#  7   day           int32
#  8   dcoilwtico    float64
#  9   store_nbr     float64
#  10  transactions  float64
#  11  id            float64
#  12  family        object
#  13  sales         float64
#  14  onpromotion   float64
#  15  city          object
#  16  state         object
#  17  type_y        object
#  18  cluster       float64
# dtypes: bool(1), float64(7), int32(3), object(8)
# memory usage: 403.5+ MB

# %%
merged_data.isna().sum()
# Out:
# type_x          0
# locale          0
# locale_name     0
# description     0
# transferred     0
# year            0
# month           0
# day             0
# dcoilwtico      0
# store_nbr       0
# transactions    0
# id              0
# family          0
# sales           0
# onpromotion     0
# city            0
# state           0
# type_y          0
# cluster         0
# dtype: int64

# %% [markdown]
# #### CATEGORICAL COLUMNS

# %%
categorical_columns = merged_data.select_dtypes(include=['object']).columns

# %%
# Select the columns you want to one-hot encode
categorical_columns = ['type_x', 'locale', 'locale_name', 'description', 'transferred', 'city', 'state', 'type_y']

# Apply one-hot encoding
df_encoded = pd.get_dummies(merged_data, columns=categorical_columns, drop_first=True)

# %%
df_encoded.info()
df_encoded.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3000888 entries, 41 to 3085943
# Data columns (total 83 columns):
#  #   Column                                Dtype
# ---  ------                                -----
#  0   transferred                           bool
#  1   year                                  int32
#  2   month                                 int32
#  3   day                                   int32
#  4   dcoilwtico                            float64
#  5   store_nbr                             float64
#  6   transactions                          float64
#  7   id                                    float64
#  8   sales                                 float64
#  9   onpromotion                           float64
#  10  cluster                               float64
#  11  family_BABY CARE                      bool
#  12  family_BEAUTY                         bool
#  13  family_BEVERAGES                      bool
#  14  family_BOOKS                          bool
#  15  family_BREAD/BAKERY                   bool
#  16  family_CELEBRATION                    bool
#  17  family_CLEANING                       bool
#  18  family_DAIRY                          bool
#  19  family_DELI                           bool
#  20  family_EGGS                           bool
#  21  family_FROZEN FOODS                   bool
#  22  family_GROCERY I                      bool
#  23  family_GROCERY II                     bool
#  24  family_HARDWARE                       bool
#  25  family_HOME AND KITCHEN I             bool
#  26  family_HOME AND KITCHEN II            bool
#  27  family_HOME APPLIANCES                bool
#  28  family_HOME CARE                      bool
#  29  family_LADIESWEAR                     bool
#  30  family_LAWN AND GARDEN                bool
#  31  family_LINGERIE                       bool
#  32  family_LIQUOR,WINE,BEER               bool
#  33  family_MAGAZINES                      bool
#  34  family_MEATS                          bool
#  35  family_PERSONAL CARE                  bool
#  36  family_PET SUPPLIES                   bool
#  37  family_PLAYERS AND ELECTRONICS        bool
#  38  family_POULTRY                        bool
#  39  family_PREPARED FOODS                 bool
#  40  family_PRODUCE                        bool
#  41  family_SCHOOL AND OFFICE SUPPLIES     bool
#  42  family_SEAFOOD                        bool
#  43  city_Babahoyo                         bool
#  44  city_Cayambe                          bool
#  45  city_Cuenca                           bool
#  46  city_Daule                            bool
#  47  city_El Carmen                        bool
#  48  city_Esmeraldas                       bool
#  49  city_Guaranda                         bool
#  50  city_Guayaquil                        bool
#  51  city_Ibarra                           bool
#  52  city_Latacunga                        bool
#  53  city_Libertad                         bool
#  54  city_Loja                             bool
#  55  city_Machala                          bool
#  56  city_Manta                            bool
#  57  city_Playas                           bool
#  58  city_Puyo                             bool
#  59  city_Quevedo                          bool
#  60  city_Quito                            bool
#  61  city_Riobamba                         bool
#  62  city_Salinas                          bool
#  63  city_Santo Domingo                    bool
#  64  state_Bolivar                         bool
#  65  state_Chimborazo                      bool
#  66  state_Cotopaxi                        bool
#  67  state_El Oro                          bool
#  68  state_Esmeraldas                      bool
#  69  state_Guayas                          bool
#  70  state_Imbabura                        bool
#  71  state_Loja                            bool
#  72  state_Los Rios                        bool
#  73  state_Manabi                          bool
#  74  state_Pastaza                         bool
#  75  state_Pichincha                       bool
#  76  state_Santa Elena                     bool
#  77  state_Santo Domingo de los Tsachilas  bool
#  78  state_Tungurahua                      bool
#  79  type_y_B                              bool
#  80  type_y_C                              bool
#  81  type_y_D                              bool
#  82  type_y_E                              bool
# dtypes: bool(73), float64(7), int32(3)
# memory usage: 426.4 MB
#     transferred  year  month  day  dcoilwtico  store_nbr  transactions  \
# 41        False  2013      8   15       104.9       47.0        1393.0
# 42        False  2013      8   15       104.9       47.0        1393.0
# 43        False  2013      8   15       104.9       47.0        1393.0
# 44        False  2013      8   15       104.9       47.0        1393.0
# 45        False  2013      8   15       104.9       47.0        1393.0
#
#           id   sales  onpromotion  ...  state_Manabi  state_Pastaza  \
# 41  404093.0   723.0          0.0  ...         False          False
# 42  404092.0  1441.0          0.0  ...         False          False
# 43  404091.0     0.0          0.0  ...         False          False
# 44  404087.0     9.0          0.0  ...         False          False
# 45  404089.0     0.0          0.0  ...         False          False
#
#     state_Pichincha  state_Santa Elena  state_Santo Domingo de los Tsachilas  \
# 41             True              False                                 False
# 42             True              False                                 False
# 43             True              False                                 False
# 44             True              False                                 False
# 45             True              False                                 False
#
#     state_Tungurahua  type_y_B  type_y_C  type_y_D  type_y_E
# 41             False     False     False     False     False
# 42             False     False     False     False     False
# 43             False     False     False     False     False
# 44             False     False     False     False     False
# 45             False     False     False     False     False
#
# [5 rows x 83 columns]

# %%
merged_data['sales'].info()
merged_data['transactions'].info()
merged_data['dcoilwtico'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 3000888 entries, 41 to 3085943
# Series name: sales
# Non-Null Count    Dtype
# --------------    -----
# 3000888 non-null  float64
# dtypes: float64(1)
# memory usage: 45.8 MB
# <class 'pandas.core.series.Series'>
# Index: 3000888 entries, 41 to 3085943
# Series name: transactions
# Non-Null Count    Dtype
# --------------    -----
# 3000888 non-null  float64
# dtypes: float64(1)
# memory usage: 45.8 MB
# <class 'pandas.core.series.Series'>
# Index: 3000888 entries, 41 to 3085943
# Series name: dcoilwtico
# Non-Null Count    Dtype
# --------------    -----
# 3000888 non-null  float64
# dtypes: float64(1)
# memory usage: 45.8 MB

# %% [markdown]
# ### FEATURE ENGINEERING

# %% [markdown]
# ### Rolling features

# %% [markdown]
# Getting the 7-day rolling average of sales

# %%
merged_data['sales_7d_avg'] = merged_data['sales'].rolling(window=7).mean()

# %% [markdown]
# Using Lag features
